# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('max_columns',50)

# %%
# create a Seriex with an arbitrary list
s = pd.Series([7, 'Heisenberg', 3.14, -1789710578, 'Happy Eating!'])
s
# Out:
# 0                7
# 1       Heisenberg
# 2             3.14
# 3      -1789710578
# 4    Happy Eating!
# dtype: object

# %%
s = pd.Series([7, 'Heisenberg', 3.14, -1789710578, 'Happy Eating!'],
              index=['A', 'Z', 'C', 'Y', 'E'])
s
# s['A']
# Out:
# A                7
# Z       Heisenberg
# C             3.14
# Y      -1789710578
# E    Happy Eating!
# dtype: object

# %%
d = {'Chicago': 1000, 'New York': 1300, 'Portland': 900, 'San Francisco': 1100,
     'Austin': 450, 'Boston': None}
type(d)
# Out:
# dict

# %%
cities= pd.Series(d)
cities['Austin']
# Out:
# 450.0

# %%
cities[['Austin','Chicago']]
# Out:
# Austin      450.0
# Chicago    1000.0
# dtype: float64

# %%
cities
# Out:
# Chicago          1000.0
# New York         1300.0
# Portland          900.0
# San Francisco    1100.0
# Austin            450.0
# Boston              NaN
# dtype: float64

# %%
cities[cities> 1100]
# Out:
# New York    1300.0
# dtype: float64

# %%
cities['Chicago'] = 1400
cities['India'] = 2000

# %%
cities
# Out:
# Chicago          1400.0
# New York         1300.0
# Portland          900.0
# San Francisco    1100.0
# Austin            450.0
# Boston              NaN
# India            2000.0
# dtype: float64

# %%
print('India' in cities)
print('San Francisco' in cities)
print('San Franciscoo' in cities)
# Out:
# True
# True
# False

# %%
cities/3
# Out:
# Chicago          466.666667
# New York         433.333333
# Portland         300.000000
# San Francisco    366.666667
# Austin           150.000000
# Boston                  NaN
# India            666.666667
# dtype: float64

# %%
cities
# Out:
# Chicago          1400.0
# New York         1300.0
# Portland          900.0
# San Francisco    1100.0
# Austin            450.0
# Boston              NaN
# India            2000.0
# dtype: float64

# %% [markdown]
# You can add two Series together, which returns a union of the two Series with the addition occurring on the shared index values. Values on either Series that did not have a shared index will produce a NULL/NaN (not a number).

# %%
print(cities[['Chicago', 'New York', 'Portland']])
print('\n')
print(cities[['Austin', 'New York']])
print('\n')
print(cities[['Chicago', 'New York', 'Portland']] + cities[['Austin', 'New York']])
# Out:
# Chicago     1400.0
# New York    1300.0
# Portland     900.0
# dtype: float64
#
#
# Austin       450.0
# New York    1300.0
# dtype: float64
#
#
# Austin         NaN
# Chicago        NaN
# New York    2600.0
# Portland       NaN
# dtype: float64

# %% [markdown]
# NULL checking can be performed with isnull and notnull.

# %%
cities.isnull()
# Out:
# Chicago          False
# New York         False
# Portland         False
# San Francisco    False
# Austin           False
# Boston            True
# India            False
# dtype: bool

# %%
# use boolean logic to grab the NULL cities
print(cities.isnull())
print('\n')
print(cities[cities.isnull()])
# Out:
# Chicago          False
# New York         False
# Portland         False
# San Francisco    False
# Austin           False
# Boston            True
# India            False
# dtype: bool
#
#
# Boston   NaN
# dtype: float64

# %%
data = {'year': [2010, 2011, 2012, 2011, 2012, 2010, 2011, 2012],
        'team': ['Bears', 'Bears', 'Bears', 'Packers', 'Packers', 'Lions', 'Lions', 'Lions'],
        'wins': [11, 8, 10, 15, 11, 6, 10, 4],
        'losses': [5, 8, 6, 1, 5, 10, 6, 12]}
football = pd.DataFrame(data, columns=['year', 'team', 'wins', 'losses'])

# %%
football
# Out:
#    year     team  wins  losses
# 0  2010    Bears    11       5
# 1  2011    Bears     8       8
# 2  2012    Bears    10       6
# 3  2011  Packers    15       1
# 4  2012  Packers    11       5
# 5  2010    Lions     6      10
# 6  2011    Lions    10       6
# 7  2012    Lions     4      12

# %%
del football

# %%
from_csv = pd.read_csv("C://Users//t.shah//Desktop//TanujGit//ExploratoryDataAnalysis-EDA//DataSet//mariano-rivera.csv")
from_csv.head()
# Out:
#    Year  Age   Tm  Lg  W  L   W-L%   ERA   G  GS  GF  CG  SHO  SV     IP   H  \
# 0  1995   25  NYY  AL  5  3  0.625  5.51  19  10   2   0    0   0   67.0  71
# 1  1996   26  NYY  AL  8  3  0.727  2.09  61   0  14   0    0   5  107.2  73
# 2  1997   27  NYY  AL  6  4  0.600  1.88  66   0  56   0    0  43   71.2  65
# 3  1998   28  NYY  AL  3  0  1.000  1.91  54   0  49   0    0  36   61.1  48
# 4  1999   29  NYY  AL  4  3  0.571  1.83  66   0  63   0    0  45   69.0  43
#
#     R  ER  HR  BB  IBB   SO  HBP  BK  WP   BF  ERA+   WHIP  H/9  HR/9  BB/9  \
# 0  43  41  11  30    0   51    2   1   0  301    84  1.507  9.5   1.5   4.0
# 1  25  25   1  34    3  130    2   0   1  425   240  0.994  6.1   0.1   2.8
# 2  17  15   5  20    6   68    0   0   2  301   239  1.186  8.2   0.6   2.5
# 3  13  13   3  17    1   36    1   0   0  246   233  1.060  7.0   0.4   2.5
# 4  15  14   2  18    3   52    3   1   2  268   257  0.884  5.6   0.3   2.3
#
#    SO/9  SO/BB         Awards
# ...

# %%
cols = ['num', 'game', 'date', 'team', 'home_away', 'opponent',
        'result', 'quarter', 'distance', 'receiver', 'score_before',
        'score_after']
no_headers = pd.read_csv('C://Users//t.shah//Desktop//TanujGit//ExploratoryDataAnalysis-EDA//DataSet//peyton-passing-TDs-2012.csv', names=cols)
no_headers.head()
# Out:
#    num  game       date team home_away opponent   result  quarter  distance  \
# 0    1     1   9/9/2012  DEN       NaN      PIT  W 31-19        3        71
# 1    2     1   9/9/2012  DEN       NaN      PIT  W 31-19        4         1
# 2    3     2  9/17/2012  DEN         @      ATL  L 21-27        2        17
# 3    4     3  9/23/2012  DEN       NaN      HOU  L 25-31        4        38
# 4    5     3  9/23/2012  DEN       NaN      HOU  L 25-31        4         6
#
#            receiver score_before  score_after
# 0  Demaryius Thomas   Trail 7-13  Lead 14-13*
# 1       Jacob Tamme  Trail 14-19  Lead 22-19*
# 2  Demaryius Thomas   Trail 0-20   Trail 7-20
# 3   Brandon Stokley  Trail 11-31  Trail 18-31
# 4     Joel Dreessen  Trail 18-31  Trail 25-31

# %%
url1 =  "C://Users//t.shah//Desktop//TanujGit//ExploratoryDataAnalysis-EDA//DataSet//u.user"
url2 =  "C://Users//t.shah//Desktop//TanujGit//ExploratoryDataAnalysis-EDA//DataSet//u.data"
url3 =  "C://Users//t.shah//Desktop//TanujGit//ExploratoryDataAnalysis-EDA//DataSet//u.item"


u_cols = ['user_id', 'age', 'sex', 'occupation', 'zip_code']
users = pd.read_csv(url1, sep='|', names=u_cols,encoding='latin-1')
users.head()



r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
ratings = pd.read_csv(url2, sep='\t', names=r_cols,encoding='latin-1')

# the movies file contains columns indicating the movie's genres
# let's only load the first five columns of the file with usecols
m_cols = ['movie_id', 'title', 'release_date', 'video_release_date', 'imdb_url']
movies = pd.read_csv(url3, sep='|', names=m_cols, usecols=range(5),encoding='latin-1')

# %%
users.head()
# Out:
#    user_id  age sex  occupation zip_code
# 0        1   24   M  technician    85711
# 1        2   53   F       other    94043
# 2        3   23   M      writer    32067
# 3        4   24   M  technician    43537
# 4        5   33   F       other    15213

# %%
ratings.head()
# Out:
#    user_id  movie_id  rating  unix_timestamp
# 0      196       242       3       881250949
# 1      186       302       3       891717742
# 2       22       377       1       878887116
# 3      244        51       2       880606923
# 4      166       346       1       886397596

# %%
movies.head()
# Out:
#    movie_id              title release_date  video_release_date  \
# 0         1   Toy Story (1995)  01-Jan-1995                 NaN
# 1         2   GoldenEye (1995)  01-Jan-1995                 NaN
# 2         3  Four Rooms (1995)  01-Jan-1995                 NaN
# 3         4  Get Shorty (1995)  01-Jan-1995                 NaN
# 4         5     Copycat (1995)  01-Jan-1995                 NaN
#
#                                             imdb_url
# 0  http://us.imdb.com/M/title-exact?Toy%20Story%2...
# 1  http://us.imdb.com/M/title-exact?GoldenEye%20(...
# 2  http://us.imdb.com/M/title-exact?Four%20Rooms%...
# 3  http://us.imdb.com/M/title-exact?Get%20Shorty%...
# 4  http://us.imdb.com/M/title-exact?Copycat%20(1995)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1682 entries, 0 to 1681
# Data columns (total 5 columns):
# movie_id              1682 non-null int64
# title                 1682 non-null object
# release_date          1681 non-null object
# video_release_date    0 non-null float64
# imdb_url              1679 non-null object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 65.8+ KB

# %%
movies.dtypes
# Out:
# movie_id                int64
# title                  object
# release_date           object
# video_release_date    float64
# imdb_url               object
# dtype: object

# %%
users.describe()
# Out:
#           user_id         age
# count  943.000000  943.000000
# mean   472.000000   34.051962
# std    272.364951   12.192740
# min      1.000000    7.000000
# 25%    236.500000   25.000000
# 50%    472.000000   31.000000
# 75%    707.500000   43.000000
# max    943.000000   73.000000

# %% [markdown]
# We can quickly see the average age of our users is just above 34 years old, with the youngest being 7 and the oldest being 73. The median age is 31, with the youngest quartile of users being 25 or younger, and the oldest quartile being at least 43.

# %%
movies[22:30]
# Out:
#     movie_id                          title release_date  video_release_date  \
# 22        23             Taxi Driver (1976)  16-Feb-1996                 NaN
# 23        24     Rumble in the Bronx (1995)  23-Feb-1996                 NaN
# 24        25           Birdcage, The (1996)  08-Mar-1996                 NaN
# 25        26  Brothers McMullen, The (1995)  01-Jan-1995                 NaN
# 26        27                Bad Boys (1995)  01-Jan-1995                 NaN
# 27        28               Apollo 13 (1995)  01-Jan-1995                 NaN
# 28        29          Batman Forever (1995)  01-Jan-1995                 NaN
# 29        30           Belle de jour (1967)  01-Jan-1967                 NaN
#
#                                              imdb_url
# 22  http://us.imdb.com/M/title-exact?Taxi%20Driver...
# 23  http://us.imdb.com/M/title-exact?Hong%20Faan%2...
# 24  http://us.imdb.com/M/title-exact?Birdcage,%20T...
# 25  http://us.imdb.com/M/title-exact?Brothers%20Mc...
# ...

# %%
'''return a Series object.'''
users['occupation'].head()
# Out:
# 0    technician
# 1         other
# 2        writer
# 3    technician
# 4         other
# Name: occupation, dtype: object

# %%
users[['age', 'zip_code']].head()
# Out:
#    age zip_code
# 0   24    85711
# 1   53    94043
# 2   23    32067
# 3   24    43537
# 4   33    15213

# %%
users.columns
# Out:
# Index(['user_id', 'age', 'sex', 'occupation', 'zip_code'], dtype='object')

# %%
users.occupation.head()
# Out:
# 0    technician
# 1         other
# 2        writer
# 3    technician
# 4         other
# Name: occupation, dtype: object

# %%
users['sex'].head()
# Out:
# 0    M
# 1    F
# 2    M
# 3    M
# 4    F
# Name: sex, dtype: object

# %%
users.head()
# Out:
#    user_id  age sex  occupation zip_code
# 0        1   24   M  technician    85711
# 1        2   53   F       other    94043
# 2        3   23   M      writer    32067
# 3        4   24   M  technician    43537
# 4        5   33   F       other    15213

# %%
users[(users.sex == 'M') & (users.age == 40)]
# Out:
#      user_id  age sex  occupation zip_code
# 18        19   40   M   librarian    02138
# 82        83   40   M       other    44133
# 115      116   40   M  healthcare    97232
# 199      200   40   M  programmer    93402
# 283      284   40   M   executive    92629
# 289      290   40   M    engineer    93550
# 308      309   40   M   scientist    70802
# 357      358   40   M    educator    10022
# 397      398   40   M       other    60008
# 564      565   40   M     student    55422
# 646      647   40   M    educator    45810
# 791      792   40   M  programmer    12205
# 841      842   40   M      writer    93055
# 917      918   40   M   scientist    70116

# %%
users.set_index('user_id').head()
# Out:
#          age sex  occupation zip_code
# user_id
# 1         24   M  technician    85711
# 2         53   F       other    94043
# 3         23   M      writer    32067
# 4         24   M  technician    43537
# 5         33   F       other    15213

# %%
users.set_index('user_id', inplace=True)

# %%
users.head()
# Out:
#          age sex  occupation zip_code
# user_id
# 1         24   M  technician    85711
# 2         53   F       other    94043
# 3         23   M      writer    32067
# 4         24   M  technician    43537
# 5         33   F       other    15213

# %% [markdown]
# !['Pandas-selections-and-indexing-768x549.png']( https://shanelynnwebsite-mid9n9g1q9y8tt.netdna-ssl.com/wp-content/uploads/2016/10/Pandas-selections-and-indexing-768x549.png )

# %%
users.iloc[4]
# Out:
# age              33
# sex               F
# occupation    other
# zip_code      15213
# Name: 5, dtype: object

# %%
users.iloc[[0,2,4],[1,2]]
# Out:
#         sex  occupation
# user_id
# 1         M  technician
# 3         M      writer
# 5         F       other

# %%
users.loc[24]
# Out:
# age               21
# sex                F
# occupation    artist
# zip_code       94533
# Name: 24, dtype: object

# %%
users.loc[4]
# Out:
# age                   24
# sex                    M
# occupation    technician
# zip_code           43537
# Name: 4, dtype: object

# %%
users.reset_index(inplace=True)
users.head()
# Out:
#    user_id  age sex  occupation zip_code
# 0        1   24   M  technician    85711
# 1        2   53   F       other    94043
# 2        3   23   M      writer    32067
# 3        4   24   M  technician    43537
# 4        5   33   F       other    15213

# %%
users.iloc[[0,1,2],[2]]
# Out:
#          occupation
# user_id
# 1        technician
# 2             other
# 3            writer

# %%
users.loc[[1,2,3],['occupation']]
# Out:
#          occupation
# user_id
# 1        technician
# 2             other
# 3            writer

# %%
users[(users['age'] == 24) & (users['sex'] == 'M' )].head()
# Out:
#          age sex  occupation zip_code
# user_id
# 1         24   M  technician    85711
# 4         24   M  technician    43537
# 31        24   M      artist    10003
# 69        24   M    engineer    55337
# 73        24   M     student    41850

# %%
users.loc[(users['age'] == 24) & (users['sex'] == 'M' ), 'occupation'].head()
# Out:
# user_id
# 1     technician
# 4     technician
# 31        artist
# 69      engineer
# 73       student
# Name: occupation, dtype: object

# %%
users.loc[(users['age'] == 24) & (users['sex'] == 'M' ), ['occupation']].head()
# Out:
#          occupation
# user_id
# 1        technician
# 4        technician
# 31           artist
# 69         engineer
# 73          student

# %%
users.reset_index(inplace= True)

# %%
users.head()
# Out:
#    user_id  age sex  occupation zip_code
# 0        1   24   M  technician    85711
# 1        2   53   F       other    94043
# 2        3   23   M      writer    32067
# 3        4   24   M  technician    43537
# 4        5   33   F       other    15213

# %%
left_frame = pd.DataFrame({'key': range(5), 
                           'left_value': ['a', 'b', 'c', 'd', 'e']})
right_frame = pd.DataFrame({'key': range(2, 7), 
                           'right_value': ['f', 'g', 'h', 'i', 'j']})
print(left_frame)
print('\n')
print(right_frame)
# Out:
#    key left_value
# 0    0          a
# 1    1          b
# 2    2          c
# 3    3          d
# 4    4          e
#
#
#    key right_value
# 0    2           f
# 1    3           g
# 2    4           h
# 3    5           i
# 4    6           j

# %%
pd.merge(right_frame,left_frame, on='key', how='inner')
# Out:
#    key right_value left_value
# 0    2           f          c
# 1    3           g          d
# 2    4           h          e

# %%
pd.merge(left_frame, right_frame, on='key', how='left')
# Out:
#    key left_value right_value
# 0    0          a         NaN
# 1    1          b         NaN
# 2    2          c           f
# 3    3          d           g
# 4    4          e           h

# %%
pd.merge(left_frame, right_frame, on='key', how='right')
# Out:
#    key left_value right_value
# 0    2          c           f
# 1    3          d           g
# 2    4          e           h
# 3    5        NaN           i
# 4    6        NaN           j

# %%
pd.merge(left_frame, right_frame, on='key', how='outer')
# Out:
#    key left_value right_value
# 0    0          a         NaN
# 1    1          b         NaN
# 2    2          c           f
# 3    3          d           g
# 4    4          e           h
# 5    5        NaN           i
# 6    6        NaN           j

# %%
pd.concat([left_frame, right_frame])
# Out:
# C:\Users\t.shah\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#    key left_value right_value
# 0    0          a         NaN
# 1    1          b         NaN
# 2    2          c         NaN
# 3    3          d         NaN
# 4    4          e         NaN
# 0    2        NaN           f
# 1    3        NaN           g
# 2    4        NaN           h
# 3    5        NaN           i
# 4    6        NaN           j

# %% [markdown]
# ## Grouping

# %%
headers = ['name', 'title', 'department', 'salary']
chicago = pd.read_csv('C://Users//t.shah//Desktop//TanujGit//ExploratoryDataAnalysis-EDA//DataSet//city-of-chicago-salaries.csv', 
                      header=0,
                      names=headers,
                      converters={'salary': lambda x: x.replace('$', '')})
chicago.head()
# Out:
#                   name                            title    department  \
# 0     ADAM,  ELIZABETH       STAFF ASSISTANT - EXCLUDED  ADMIN HEARNG
# 1       BREWER,  JAMIE           ADMINISTRATIVE ASST II  ADMIN HEARNG
# 2  BRIGHAM,  DEBORAH A            ADMINISTRATIVE SUPVSR  ADMIN HEARNG
# 3    BROWN,  ELOUISE V           ADMINISTRATIVE ASST II  ADMIN HEARNG
# 4    BURAGE,  LORRIE A  CUSTOMER ACCOUNT REPRESENTATIVE  ADMIN HEARNG
#
#      salary
# 0  70380.00
# 1  60600.00
# 2
# 3  63456.00
# 4  50280.00

# %%
chicago.head()
# Out:
#                   name                            title    department  \
# 0     ADAM,  ELIZABETH       STAFF ASSISTANT - EXCLUDED  ADMIN HEARNG
# 1       BREWER,  JAMIE           ADMINISTRATIVE ASST II  ADMIN HEARNG
# 2  BRIGHAM,  DEBORAH A            ADMINISTRATIVE SUPVSR  ADMIN HEARNG
# 3    BROWN,  ELOUISE V           ADMINISTRATIVE ASST II  ADMIN HEARNG
# 4    BURAGE,  LORRIE A  CUSTOMER ACCOUNT REPRESENTATIVE  ADMIN HEARNG
#
#      salary
# 0  70380.00
# 1  60600.00
# 2
# 3  63456.00
# 4  50280.00

# %%
by_dept = chicago.groupby('department')['name']
by_dept.count().head()
# Out:
# department
# ADMIN HEARNG           42
# ANIMAL CONTRL          61
# AVIATION             1218
# BOARD OF ELECTION     110
# BOARD OF ETHICS         9
# Name: name, dtype: int64

# %%
chicago['salary'] = pd.to_numeric(chicago['salary'])

# %%
pd.set_option('float_format', '{:f}'.format)
chicago.groupby('department')['salary'].sum().head()
# Out:
# department
# ADMIN HEARNG         2890872.000000
# ANIMAL CONTRL        3484408.800000
# AVIATION            86037387.440000
# BOARD OF ELECTION    6130176.000000
# BOARD OF ETHICS       734856.000000
# Name: salary, dtype: float64

# %%
pd.set_option('float_format', '{:f}'.format)
chicago.groupby(['department', 'title'])['salary'].mean().head()
# Out:
# department    title
# ADMIN HEARNG  ADMINISTRATIVE ASST II                        55642.736842
#               ADMINISTRATIVE ASST III                       63516.000000
#               ADMINISTRATIVE SERVICES OFFICER II            88812.000000
#               ADMINISTRATIVE SUPVSR                                  nan
#               ASST MANAGER OF ADMINISTRATIVE ADJUDICATION   93432.000000
# Name: salary, dtype: float64

# %%
chicago.groupby('department')['title'].nunique()
# Out:
# department
# ADMIN HEARNG              15
# ANIMAL CONTRL             19
# AVIATION                 125
# BOARD OF ELECTION         23
# BOARD OF ETHICS            9
# BUDGET & MGMT             24
# BUILDINGS                 49
# BUSINESS AFFAIRS          64
# CITY CLERK                39
# CITY COUNCIL              28
# COMMUNITY DEVELOPMENT     71
# CULTURAL AFFAIRS          39
# DISABILITIES              22
# DoIT                      40
# FAMILY & SUPPORT         113
# FINANCE                   98
# FIRE                      91
# GENERAL SERVICES         117
# HEALTH                   118
# HUMAN RELATIONS           12
# HUMAN RESOURCES           32
# INSPECTOR GEN             23
# IPRA                      22
# LAW                       50
# LICENSE APPL COMM          1
# MAYOR'S OFFICE            28
# OEMC                      69
# POLICE                   130
# POLICE BOARD               2
# PROCUREMENT               30
# PUBLIC LIBRARY            72
# ...

# %%
by_dept.title.nunique()
# Out:
# department
# ADMIN HEARNG              15
# ANIMAL CONTRL             19
# AVIATION                 125
# BOARD OF ELECTION         23
# BOARD OF ETHICS            9
# BUDGET & MGMT             24
# BUILDINGS                 49
# BUSINESS AFFAIRS          64
# CITY CLERK                39
# CITY COUNCIL              28
# COMMUNITY DEVELOPMENT     71
# CULTURAL AFFAIRS          39
# DISABILITIES              22
# DoIT                      40
# FAMILY & SUPPORT         113
# FINANCE                   98
# FIRE                      91
# GENERAL SERVICES         117
# HEALTH                   118
# HUMAN RELATIONS           12
# HUMAN RESOURCES           32
# INSPECTOR GEN             23
# IPRA                      22
# LAW                       50
# LICENSE APPL COMM          1
# MAYOR'S OFFICE            28
# OEMC                      69
# POLICE                   130
# POLICE BOARD               2
# PROCUREMENT               30
# PUBLIC LIBRARY            72
# ...

# %% [markdown]
# What if we wanted to see the highest paid employee within each department. Given our current dataset, we'd have to do something like this in SQL:
#
#     SELECT *
#     FROM chicago c
#     INNER JOIN (
#         SELECT department, max(salary) max_salary
#         FROM chicago
#         GROUP BY department
#     ) m
#     ON c.department = m.department
#     AND c.salary = m.max_salary;

# %%
dep_sum_salary = chicago.groupby('department')['salary'].max()
dep_sum_salary.head()
# Out:
# department
# ADMIN HEARNG        156420.000000
# ANIMAL CONTRL       134124.000000
# AVIATION            186576.000000
# BOARD OF ELECTION   124320.000000
# BOARD OF ETHICS     125532.000000
# Name: salary, dtype: float64

# %%
result  = pd.merge(chicago, dep_sum_salary , on= ['department'], how = 'inner' )
result[result['salary_x'] ==result['salary_y']]
# Out:
#                            name                                         title  \
# 17         JACKOWIAK,  PATRICIA                DIR OF ADMINISTRATIVE HEARINGS
# 44            ALFRED,  SANDRA L      EXECUTIVE DIR OF ANIMAL CARE AND CONTROL
# 134      ANDOLINO,  ROSEMARIE S                      COMMISSIONER OF AVIATION
# 1327       BATEMAN,  KELLY ANNE           DEPUTY CHIEF ADMINISTRATIVE OFFICER
# 1431            BERLIN,  STEVEN               EXECUTIVE DIR - BOARD OF ETHICS
# 1455         HOLT,  ALEXANDRA D                                    BUDGET DIR
# 1628       MERCHANT,  MICHAEL R                     COMMISSIONER OF BUILDINGS
# 1810         KRIMBEL,  ROSEMARY  COMMISSIONER OF BUS AFAIRS AND CONSUMER PROT
# 1961         MENDOZA,  SUSANA A                                    CITY CLERK
# 2159           KAIDEN,  MARLA M                  CHIEF ADMINISTRATIVE OFFICER
# 2486          MOONEY,  ANDREW J        COMMISSIONER OF HOUSING & ECONOMIC DEV
# ...

# %%
chicago[chicago['department'] == 'LAW'].head()
# Out:
#                      name                            title department  \
# 10470  ACHILLES,  AMBER L  ASST CORPORATION COUNSEL SUPVSR        LAW
# 10471   ACUFF,  KRISTIN L         ASST CORPORATION COUNSEL        LAW
# 10472    ADAMS,  OLIVIA I                  LEGAL SECRETARY        LAW
# 10473  AGUIAR,  WILLIAM M  ASST CORPORATION COUNSEL SUPVSR        LAW
# 10474       AKERS,  AMY A            EXECUTIVE SECRETARY I        LAW
#
#              salary
# 10470  91068.000000
# 10471  66960.000000
# 10472  72936.000000
# 10473 106416.000000
# 10474  45684.000000

# %%
chicago[chicago.department == 'LAW'].count()
# Out:
# name          450
# title         450
# department    450
# salary        450
# dtype: int64

# %% [markdown]
# ### Department wise Rank

# %%
chicago.sort_values('salary', ascending=False, inplace=True)

# %%
chicago.head()
# Out:
#                         name                           title      department  \
# 19996    MC CARTHY,  GARRY F        SUPERINTENDENT OF POLICE          POLICE
# 10938         EMANUEL,  RAHM                           MAYOR  MAYOR'S OFFICE
# 7838       SANTIAGO,  JOSE A               FIRE COMMISSIONER            FIRE
# 8154   STEWART III,  CHARLES  FIRST DEPUTY FIRE COMMISSIONER            FIRE
# 25740     WYSINGER,  ALFONZA     FIRST DEPUTY SUPERINTENDENT          POLICE
#
#              salary
# 19996 260004.000000
# 10938 216210.000000
# 7838  202728.000000
# 8154  188316.000000
# 25740 188316.000000

# %%
def ranker(df):
    """Assigns a rank to each employee based on salary, with 1 being the highest paid.
    Assumes the data is DESC sorted."""
    df['dept_rank'] = np.arange(len(df)) + 1
    return df
    
chicago.sort_values('salary', ascending=False, inplace=True)
chicago = chicago.groupby('department').apply(ranker)

# %%
chicago[chicago.department == 'BOARD OF ETHICS']
# Out:
#                        name                            title       department  \
# 1431        BERLIN,  STEVEN  EXECUTIVE DIR - BOARD OF ETHICS  BOARD OF ETHICS
# 1434        EILERS,  LISA S                       DEPUTY DIR  BOARD OF ETHICS
# 1439  SUPERFINE,  RICHARD J  LEGAL COUNSEL - BOARD OF ETHICS  BOARD OF ETHICS
# 1438        PRIMER,  EDWARD                      PROGRAM DIR  BOARD OF ETHICS
# 1432      CASILLAS,  PAULLY                       STAFF ASST  BOARD OF ETHICS
# 1436    JOHNSON,  JEFFERY C        COORD OF SPECIAL PROJECTS  BOARD OF ETHICS
# 1433          COLLAZO,  ANA            INVESTIGATOR - ETHICS  BOARD OF ETHICS
# 1435    JACKSON,  DORETHA L             ASST TO THE EXEC DIR  BOARD OF ETHICS
# 1437    METTELMAN,  SHANNON       EXEC ADMINISTRATIVE ASST I  BOARD OF ETHICS
#
#             salary  dept_rank
# 1431 125532.000000          1
# 1434 118080.000000          2
# 1439  84780.000000          3
# 1438  76512.000000          4
# 1432  75240.000000          5
# ...

# %%
url1 =  "C://Users//t.shah//Desktop//TanujGit//ExploratoryDataAnalysis-EDA//DataSet//u.user"
url2 =  "C://Users//t.shah//Desktop//TanujGit//ExploratoryDataAnalysis-EDA//DataSet//u.data"
url3 =  "C://Users//t.shah//Desktop//TanujGit//ExploratoryDataAnalysis-EDA//DataSet//u.item"

u_cols = ['user_id', 'age', 'sex', 'occupation', 'zip_code']
users = pd.read_csv(url1, sep='|', names=u_cols,encoding='latin-1')
users.head()

r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
ratings = pd.read_csv(url2, sep='\t', names=r_cols,encoding='latin-1')

# the movies file contains columns indicating the movie's genres
# let's only load the first five columns of the file with usecols
m_cols = ['movie_id', 'title', 'release_date', 'video_release_date', 'imdb_url']
movies = pd.read_csv(url3, sep='|', names=m_cols, usecols=range(5),encoding='latin-1')

# %%
users.head()
# Out:
#    user_id  age sex  occupation zip_code
# 0        1   24   M  technician    85711
# 1        2   53   F       other    94043
# 2        3   23   M      writer    32067
# 3        4   24   M  technician    43537
# 4        5   33   F       other    15213

# %%
ratings.head()
# Out:
#    user_id  movie_id  rating  unix_timestamp
# 0      196       242       3       881250949
# 1      186       302       3       891717742
# 2       22       377       1       878887116
# 3      244        51       2       880606923
# 4      166       346       1       886397596

# %%
movies.head()
# Out:
#    movie_id              title release_date  video_release_date  \
# 0         1   Toy Story (1995)  01-Jan-1995                 nan
# 1         2   GoldenEye (1995)  01-Jan-1995                 nan
# 2         3  Four Rooms (1995)  01-Jan-1995                 nan
# 3         4  Get Shorty (1995)  01-Jan-1995                 nan
# 4         5     Copycat (1995)  01-Jan-1995                 nan
#
#                                             imdb_url
# 0  http://us.imdb.com/M/title-exact?Toy%20Story%2...
# 1  http://us.imdb.com/M/title-exact?GoldenEye%20(...
# 2  http://us.imdb.com/M/title-exact?Four%20Rooms%...
# 3  http://us.imdb.com/M/title-exact?Get%20Shorty%...
# 4  http://us.imdb.com/M/title-exact?Copycat%20(1995)

# %%
movie_ratings = pd.merge(movies, ratings)
movie_ratings.head()
# Out:
#    movie_id             title release_date  video_release_date  \
# 0         1  Toy Story (1995)  01-Jan-1995                 nan
# 1         1  Toy Story (1995)  01-Jan-1995                 nan
# 2         1  Toy Story (1995)  01-Jan-1995                 nan
# 3         1  Toy Story (1995)  01-Jan-1995                 nan
# 4         1  Toy Story (1995)  01-Jan-1995                 nan
#
#                                             imdb_url  user_id  rating  \
# 0  http://us.imdb.com/M/title-exact?Toy%20Story%2...      308       4
# 1  http://us.imdb.com/M/title-exact?Toy%20Story%2...      287       5
# 2  http://us.imdb.com/M/title-exact?Toy%20Story%2...      148       4
# 3  http://us.imdb.com/M/title-exact?Toy%20Story%2...      280       4
# 4  http://us.imdb.com/M/title-exact?Toy%20Story%2...       66       3
#
#    unix_timestamp
# 0       887736532
# 1       875334088
# 2       877019411
# 3       891700426
# 4       883601324

# %%
lens = pd.merge(movie_ratings, users)
lens.head()
# Out:
#    movie_id                  title release_date  video_release_date  \
# 0         1       Toy Story (1995)  01-Jan-1995                 nan
# 1         4      Get Shorty (1995)  01-Jan-1995                 nan
# 2         5         Copycat (1995)  01-Jan-1995                 nan
# 3         7  Twelve Monkeys (1995)  01-Jan-1995                 nan
# 4         8            Babe (1995)  01-Jan-1995                 nan
#
#                                             imdb_url  user_id  rating  \
# 0  http://us.imdb.com/M/title-exact?Toy%20Story%2...      308       4
# 1  http://us.imdb.com/M/title-exact?Get%20Shorty%...      308       5
# 2  http://us.imdb.com/M/title-exact?Copycat%20(1995)      308       4
# 3  http://us.imdb.com/M/title-exact?Twelve%20Monk...      308       4
# 4     http://us.imdb.com/M/title-exact?Babe%20(1995)      308       5
#
#    unix_timestamp  age sex occupation zip_code
# 0       887736532   60   M    retired    95076
# ...

# %%
lens.to_csv("C://Users//t.shah//Desktop//TanujGit//ExploratoryDataAnalysis-EDA//DataSet//lens.csv")

# %% [markdown]
# #### What are the 25 most rated movies?

# %%
result  = lens.groupby('title')['rating'].count().sort_values(ascending=False)[:25]
result.nlargest(25)

# lens.groupby('title')['rating'].count().sort_values(ascending=False)[:25]
# lens.groupby('title')['rating'].size().sort_values(ascending=False)[:25]
# lens.title.value_counts()[:25]
# Out:
# title
# Star Wars (1977)                             583
# Contact (1997)                               509
# Fargo (1996)                                 508
# Return of the Jedi (1983)                    507
# Liar Liar (1997)                             485
# English Patient, The (1996)                  481
# Scream (1996)                                478
# Toy Story (1995)                             452
# Air Force One (1997)                         431
# Independence Day (ID4) (1996)                429
# Raiders of the Lost Ark (1981)               420
# Godfather, The (1972)                        413
# Pulp Fiction (1994)                          394
# Twelve Monkeys (1995)                        392
# Silence of the Lambs, The (1991)             390
# Jerry Maguire (1996)                         384
# Chasing Amy (1997)                           379
# Rock, The (1996)                             378
# Empire Strikes Back, The (1980)              367
# ...

# %% [markdown]
# ### Which movies are most highly rated?

# %%
lens.groupby('title')['rating'].mean()
lens.groupby('title')['rating'].size()

movie_stats = lens.groupby('title').agg({'rating': [np.size, np.mean]})
# movie_stats = lens.groupby('title').rating.agg([np.size, np.mean])
movie_stats.head()
# Out:
#                           rating
#                             size     mean
# title
# 'Til There Was You (1997)      9 2.333333
# 1-900 (1994)                   5 2.600000
# 101 Dalmatians (1996)        109 2.908257
# 12 Angry Men (1957)          125 4.344000
# 187 (1997)                    41 3.024390

# %%
# sort by rating average
movie_stats.sort_values([('rating', 'mean')], ascending=False).head()
# Out:
#                                            rating
#                                              size     mean
# title
# They Made Me a Criminal (1939)                  1 5.000000
# Marlene Dietrich: Shadow and Light (1996)       1 5.000000
# Saint of Fort Washington, The (1993)            2 5.000000
# Someone Else's America (1995)                   1 5.000000
# Star Kid (1997)                                 3 5.000000

# %% [markdown]
# ### The above movies are rated so rarely that we can't count them as quality films. Let's only look at movies that have been rated at least 100 times.

# %%
atleast_100 = movie_stats.rating['size'] >100
movie_stats[atleast_100].sort_values([('rating', 'mean')], ascending=False)[:15]
# Out:
#                                        rating
#                                          size     mean
# title
# Close Shave, A (1995)                     112 4.491071
# Schindler's List (1993)                   298 4.466443
# Wrong Trousers, The (1993)                118 4.466102
# Casablanca (1942)                         243 4.456790
# Shawshank Redemption, The (1994)          283 4.445230
# Rear Window (1954)                        209 4.387560
# Usual Suspects, The (1995)                267 4.385768
# Star Wars (1977)                          583 4.358491
# 12 Angry Men (1957)                       125 4.344000
# Citizen Kane (1941)                       198 4.292929
# To Kill a Mockingbird (1962)              219 4.292237
# One Flew Over the Cuckoo's Nest (1975)    264 4.291667
# Silence of the Lambs, The (1991)          390 4.289744
# North by Northwest (1959)                 179 4.284916
# Godfather, The (1972)                     413 4.283293

# %% [markdown]
# We broke this question down into many parts, so here's the Python needed to get the 15 movies with the highest average rating, requiring that they had at least 100 ratings:
#
#     movie_stats = lens.groupby('title').agg({'rating': [np.size, np.mean]})
#         atleast_100 = movie_stats['rating'].size >= 100
#         movie_stats[atleast_100].sort_values([('rating', 'mean')], ascending=False)[:15]
# The SQL equivalent would be:
#
#     SELECT title, COUNT(1) size, AVG(rating) mean
#     FROM lens
#     GROUP BY title
#     HAVING COUNT(1) >= 100
#     ORDER BY 3 DESC
#     LIMIT 15;

# %% [markdown]
# #### Limiting our population going forward
#
# Going forward, let's only look at the 50 most rated movies. Let's make a Series of movies that meet this threshold so we can use it for filtering later.
#
# The SQL to match this would be:
#
#     CREATE TABLE most_50 AS (
#         SELECT movie_id, COUNT(1)
#         FROM lens
#         GROUP BY movie_id
#         ORDER BY 2 DESC
#         LIMIT 50
#     );
#
# This table would then allow us to use EXISTS, IN, or JOIN whenever we wanted to filter our results. Here's an example using EXISTS:
#
#     SELECT *
#     FROM lens
#     WHERE EXISTS (SELECT 1 FROM most_50 WHERE lens.movie_id = most_50.movie_id);

# %%
most_50 = lens.groupby('movie_id').size().sort_values(ascending=False)[:50]

# %% [markdown]
# ### Which movies are most controversial amongst different ages?
#
# Let's look at how these movies are viewed across different age groups. First, let's look at how age is distributed amongst our users.

# %%
import matplotlib.pyplot as plt
users.age.plot.hist(bins=30)
plt.title("Distribution of users' ages")
plt.ylabel('count of users')
plt.xlabel('age');

# %%
labels = ['0-9', '10-19', '20-29', '30-39', '40-49', '50-59', '60-69', '70-79']
lens['age_group'] = pd.cut(lens.age, range(0, 81, 10), right=False, labels=labels)

# %% [markdown]
# pandas.cut allows you to bin numeric data. In the above lines, we first created labels to name our bins, then split our users into eight bins of ten years (0-9, 10-19, 20-29, etc.). Our use of right=False told the function that we wanted the bins to be exclusive of the max age in the bin (e.g. a 30 year old user gets the 30s label).

# %%
lens[['age', 'age_group']].drop_duplicates()[:10]
# Out:
#        age age_group
# 48743   49     40-49
# 74879   57     50-59
# 20917   20     20-29
# 46625   19     10-19
# 91551   38     30-39
# 86864   40     40-49
# 76952   56     50-59
# 95815   32     30-39
# 67953   34     30-39
# 85334   21     20-29

# %%
lens.groupby('age_group').agg({'rating': [np.size, np.mean]})
# Out:
#           rating
#             size     mean
# age_group
# 0-9           43 3.767442
# 10-19       8181 3.486126
# 20-29      39535 3.467333
# 30-39      25696 3.554444
# 40-49      15021 3.591772
# 50-59       8704 3.635800
# 60-69       2623 3.648875
# 70-79        197 3.649746

# %% [markdown]
# Young users seem a bit more critical than other age groups. Let's look at how the 50 most rated movies are viewed across each age group. We can use the most_50 Series we created earlier for filtering.

# %%
lens.set_index('movie_id', inplace=True)
by_age = lens.loc[most_50.index].groupby(['title', 'age_group'])
by_age.rating.mean().head(15)
# Out:
# title                 age_group
# Air Force One (1997)  10-19       3.647059
#                       20-29       3.666667
#                       30-39       3.570000
#                       40-49       3.555556
#                       50-59       3.750000
#                       60-69       3.666667
#                       70-79       3.666667
# Alien (1979)          10-19       4.111111
#                       20-29       4.026087
#                       30-39       4.103448
#                       40-49       3.833333
#                       50-59       4.272727
#                       60-69       3.500000
#                       70-79       4.000000
# Aliens (1986)         10-19       4.050000
# Name: rating, dtype: float64

# %% [markdown]
# Notice that both the title and age group are indexes here, with the average rating value being a Series. This is going to produce a really long list of values.
#
# Wouldn't it be nice to see the data as a table? Each title as a row, each age group as a column, and the average rating in each cell.
#
# Behold! The magic of unstack!

# %%
by_age.rating.mean().unstack(1).fillna(0)[10:20]
# Out:
# age_group                              0-9    10-19    20-29    30-39  \
# title
# E.T. the Extra-Terrestrial (1982) 0.000000 3.680000 3.609091 3.806818
# Empire Strikes Back, The (1980)   4.000000 4.642857 4.311688 4.052083
# English Patient, The (1996)       5.000000 3.739130 3.571429 3.621849
# Fargo (1996)                      0.000000 3.937500 4.010471 4.230769
# Forrest Gump (1994)               5.000000 4.047619 3.785714 3.861702
# Fugitive, The (1993)              0.000000 4.320000 3.969925 3.981481
# Full Monty, The (1997)            0.000000 3.421053 4.056818 3.933333
# Godfather, The (1972)             0.000000 4.400000 4.345070 4.412844
# Groundhog Day (1993)              0.000000 3.476190 3.798246 3.786667
# Independence Day (ID4) (1996)     0.000000 3.595238 3.291429 3.389381
#
# age_group                            40-49    50-59    60-69    70-79
# title
# E.T. the Extra-Terrestrial (1982) 4.160000 4.368421 4.375000 0.000000
# ...

# %%
lens.reset_index('movie_id', inplace=True)

# %%
pivoted = lens.pivot_table(index=['movie_id', 'title'],
                           columns=['sex'],
                           values='rating',
                           fill_value=0)
pivoted.head()
# Out:
# sex                               F        M
# movie_id title
# 1        Toy Story (1995)  3.789916 3.909910
# 2        GoldenEye (1995)  3.368421 3.178571
# 3        Four Rooms (1995) 2.687500 3.108108
# 4        Get Shorty (1995) 3.400000 3.591463
# 5        Copycat (1995)    3.772727 3.140625

# %%
pivoted['diff'] = pivoted.M - pivoted.F
pivoted.head()
# Out:
# sex                               F        M      diff
# movie_id title
# 1        Toy Story (1995)  3.789916 3.909910  0.119994
# 2        GoldenEye (1995)  3.368421 3.178571 -0.189850
# 3        Four Rooms (1995) 2.687500 3.108108  0.420608
# 4        Get Shorty (1995) 3.400000 3.591463  0.191463
# 5        Copycat (1995)    3.772727 3.140625 -0.632102

# %%
pivoted.reset_index('movie_id', inplace=True)
disagreements = pivoted[pivoted.movie_id.isin(most_50.index)]['diff']
disagreements.sort_values().plot(kind='barh', figsize=[9, 15])
plt.title('Male vs. Female Avg. Ratings\n(Difference > 0 = Favored by Men)')
plt.ylabel('Title')
plt.xlabel('Average Rating Difference');
